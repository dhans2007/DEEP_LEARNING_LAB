# %% [markdown]
# <a href="https://colab.research.google.com/github/dhans2007/DEEP_LEARNING_LAB/blob/main/EXERCISE_4_PART_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
from PIL import Image
import os
#DHANESH VC 24BAD018
#LOAD HUGGING FACE MODEL

classifier = pipeline(
    "image-classification",
    model="google/vit-base-patch16-224"
)

print("Hugging Face ViT model loaded successfully!")
# Out:
# Loading weights: 100%|██████████| 200/200 [00:00<00:00, 11510.48it/s]
# Hugging Face ViT model loaded successfully!

# %%
#SELECT SAMPLE IMAGE

image_path = "dataset/test/forest"

# Get first image from folder
image_files = os.listdir(image_path)

first_image = os.path.join(
    image_path,
    image_files[0]
)

print("\nTesting image:")
print(first_image)


#LOAD IMAGE
image = Image.open(first_image).convert("RGB")
# Out:
# Testing image:
# dataset/test/forest\20056.jpg

# %%
#PREDICT

results = classifier(image)

print("\nHugging Face Predictions:")
print("==========================")

for result in results[:5]:

    print(
        result["label"],
        "->",
        round(result["score"], 4)
    )
# Out:
# Hugging Face Predictions:
# ...
# maze, labyrinth -> 0.0202
# valley, vale -> 0.0201
# lakeside, lakeshore -> 0.0186
# spotlight, spot -> 0.0128
# mountain bike, all-terrain bike, off-roader -> 0.0109
